# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('datasets/datos_abiertos_covid19/200610COVID19MEXICO.csv', encoding='utf8', sep=',')

# %%
data.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-06-10      0f69b4       2       3          15     2
# 1          2020-06-10      1c79cc       2       3          15     2
# 2          2020-06-10      140aab       2       4           9     2
# 3          2020-06-10      051c09       2       4           2     2
# 4          2020-06-10      1c8c37       2       4           9     2
# 5          2020-06-10      157813       2       4          15     1
# 6          2020-06-10      1b2125       2       3           2     1
# 7          2020-06-10      1a81fc       2       4           9     1
# 8          2020-06-10      166ede       2       4           9     2
# 9          2020-06-10      0c5853       2       4          12     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0            7           15            106              1  ...              2
# ...

# %%
data.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
plt.hist(data["EDAD"], bins=20)
# Out:
# (array([6.4600e+03, 4.3160e+03, 5.9240e+03, 1.7767e+04, 4.5730e+04,
#         5.4103e+04, 5.2987e+04, 4.9304e+04, 4.2978e+04, 3.2295e+04,
#         2.2020e+04, 1.4751e+04, 9.7020e+03, 6.2630e+03, 3.2620e+03,
#         1.1900e+03, 2.6800e+02, 2.6000e+01, 8.0000e+00, 8.0000e+00]),
#  array([  0.,   6.,  12.,  18.,  24.,  30.,  36.,  42.,  48.,  54.,  60.,
#          66.,  72.,  78.,  84.,  90.,  96., 102., 108., 114., 120.]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data["FECHA_SINTOMAS"], bins=100)
# Out:
# (array([1.7452e+04, 8.0760e+03, 3.2680e+03, 1.3286e+04, 4.4890e+03,
#         2.4560e+03, 1.4483e+04, 1.5980e+03, 5.9890e+03, 1.0253e+04,
#         2.5000e+03, 1.0030e+04, 3.8000e+03, 1.3472e+04, 6.6270e+03,
#         4.3820e+03, 3.0040e+03, 5.9520e+03, 6.7950e+03, 2.6050e+03,
#         2.7780e+03, 6.5530e+03, 3.6660e+03, 1.9270e+03, 7.0270e+03,
#         1.4150e+03, 1.0631e+04, 1.2254e+04, 4.6330e+03, 6.8210e+03,
#         1.2740e+03, 3.9990e+03, 7.0450e+03, 4.9400e+03, 8.0850e+03,
#         7.2100e+03, 1.0788e+04, 1.5140e+03, 1.5160e+03, 1.1312e+04,
#         7.1690e+03, 8.6760e+03, 6.6190e+03, 7.5400e+03, 8.6730e+03,
#         1.3195e+04, 6.1870e+03, 7.0740e+03, 1.1310e+03, 7.4020e+03,
#         1.4080e+04, 6.5230e+03, 7.2710e+03, 7.0400e+02, 1.5970e+03,
#         3.6880e+03, 4.2100e+02, 2.7700e+02, 1.1000e+02, 1.2700e+02,
#         3.6300e+02, 3.8000e+01, 1.1400e+02, 1.3200e+02, 1.4000e+01,
#         1.0300e+02, 1.8830e+03, 8.2000e+01, 8.6000e+01, 1.9000e+01,
# ...

# %%
sum(data["RESULTADO"] == 3)#Sospechosos
# Out:
# 53608

# %%
sum(data["RESULTADO"] == 2)#Descartados
# Out:
# 186570

# %%
sum(data["RESULTADO"] == 1) #Confirmados
# Out:
# 129184

# %%
plt.hist(data["MUNICIPIO_RES"])
# Out:
# (array([3.2560e+05, 4.1262e+04, 6.2000e+02, 1.0970e+03, 2.9500e+02,
#         4.7000e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.8000e+01]),
#  array([  1. , 100.8, 200.6, 300.4, 400.2, 500. , 599.8, 699.6, 799.4,
#         899.2, 999. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["RESULTADO"])
# Out:
# (array([129184.,      0.,      0.,      0.,      0., 186570.,      0.,
#              0.,      0.,  53608.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <a list of 10 Patch objects>)

# %%
data["EDAD"].mean()
# Out:
# 42.589362197518966

# %%
data["FECHA_DEF"][:50]
# Out:
# 0     9999-99-99
# 1     9999-99-99
# 2     9999-99-99
# 3     9999-99-99
# 4     9999-99-99
# 5     9999-99-99
# 6     9999-99-99
# 7     9999-99-99
# 8     9999-99-99
# 9     9999-99-99
# 10    9999-99-99
# 11    2020-05-06
# 12    9999-99-99
# 13    9999-99-99
# 14    9999-99-99
# 15    2020-04-13
# 16    2020-04-09
# 17    9999-99-99
# 18    9999-99-99
# 19    9999-99-99
# 20    9999-99-99
# 21    9999-99-99
# 22    2020-05-11
# 23    9999-99-99
# 24    9999-99-99
# 25    9999-99-99
# 26    9999-99-99
# 27    9999-99-99
# 28    9999-99-99
# 29    9999-99-99
# 30    9999-99-99
# 31    9999-99-99
# 32    9999-99-99
# 33    9999-99-99
# 34    2020-05-03
# 35    9999-99-99
# 36    9999-99-99
# 37    9999-99-99
# 38    9999-99-99
# 39    9999-99-99
# 40    9999-99-99
# 41    9999-99-99
# 42    9999-99-99
# 43    9999-99-99
# 44    9999-99-99
# 45    2020-04-11
# 46    9999-99-99
# 47    9999-99-99
# 48    9999-99-99
# 49    9999-99-99
# Name: FECHA_DEF, dtype: object

# %% [markdown]
# # TABAQUISMO

# %%
data_tab = data

# %%
data_tab.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
data_tab = data_tab[["ORIGEN", "SEXO", "FECHA_SINTOMAS", "FECHA_DEF", "INTUBADO", "EDAD", "RESULTADO", "MIGRANTE"]]

# %%
data_tab
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  EDAD  RESULTADO  \
# 0            2     2     2020-05-25  9999-99-99        97    53          1
# 1            2     2     2020-05-31  9999-99-99         2    59          1
# 2            2     2     2020-04-20  9999-99-99        97    34          1
# 3            2     2     2020-04-24  9999-99-99        97    45          1
# 4            2     2     2020-04-23  9999-99-99         2    53          1
# ...        ...   ...            ...         ...       ...   ...        ...
# 369357       2     2     2020-05-27  9999-99-99        97    51          3
# 369358       1     2     2020-04-19  9999-99-99         2    96          3
# 369359       2     1     2020-06-09  9999-99-99        97    46          3
# 369360       2     1     2020-06-05  9999-99-99        97    40          3
# 369361       1     2     2020-06-09  9999-99-99        97    40          3
#
#         MIGRANTE
# 0             99
# 1             99
# ...

# %%
data_tab = data_tab.rename(columns={'FECHA_DEF': 'FECHA_DEFUNCION'})

# %%
data_tab
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  \
# 0            2     2     2020-05-25      9999-99-99        97    53
# 1            2     2     2020-05-31      9999-99-99         2    59
# 2            2     2     2020-04-20      9999-99-99        97    34
# 3            2     2     2020-04-24      9999-99-99        97    45
# 4            2     2     2020-04-23      9999-99-99         2    53
# ...        ...   ...            ...             ...       ...   ...
# 369357       2     2     2020-05-27      9999-99-99        97    51
# 369358       1     2     2020-04-19      9999-99-99         2    96
# 369359       2     1     2020-06-09      9999-99-99        97    46
# 369360       2     1     2020-06-05      9999-99-99        97    40
# 369361       1     2     2020-06-09      9999-99-99        97    40
#
#         RESULTADO  MIGRANTE
# 0               1        99
# 1               1        99
# 2               1        99
# 3               1        99
# ...

# %%
data_tab.dtypes
# Out:
# ORIGEN              int64
# SEXO                int64
# FECHA_SINTOMAS     object
# FECHA_DEFUNCION    object
# INTUBADO            int64
# EDAD                int64
# RESULTADO           int64
# MIGRANTE            int64
# dtype: object

# %%
data_tab["FECHA_SINTOMAS"] = pd.to_datetime(data_tab.FECHA_SINTOMAS)

# %%
data_tab
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  \
# 0            2     2     2020-05-25      9999-99-99        97    53
# 1            2     2     2020-05-31      9999-99-99         2    59
# 2            2     2     2020-04-20      9999-99-99        97    34
# 3            2     2     2020-04-24      9999-99-99        97    45
# 4            2     2     2020-04-23      9999-99-99         2    53
# ...        ...   ...            ...             ...       ...   ...
# 369357       2     2     2020-05-27      9999-99-99        97    51
# 369358       1     2     2020-04-19      9999-99-99         2    96
# 369359       2     1     2020-06-09      9999-99-99        97    46
# 369360       2     1     2020-06-05      9999-99-99        97    40
# 369361       1     2     2020-06-09      9999-99-99        97    40
#
#         RESULTADO  MIGRANTE
# 0               1        99
# 1               1        99
# 2               1        99
# 3               1        99
# ...

# %% [markdown]
# ### Tabaquismo - defuncion

# %%
data_tab_def = data_tab

# %%
data_tab_def
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  \
# 0            2     2     2020-05-25      9999-99-99        97    53
# 1            2     2     2020-05-31      9999-99-99         2    59
# 2            2     2     2020-04-20      9999-99-99        97    34
# 3            2     2     2020-04-24      9999-99-99        97    45
# 4            2     2     2020-04-23      9999-99-99         2    53
# ...        ...   ...            ...             ...       ...   ...
# 369357       2     2     2020-05-27      9999-99-99        97    51
# 369358       1     2     2020-04-19      9999-99-99         2    96
# 369359       2     1     2020-06-09      9999-99-99        97    46
# 369360       2     1     2020-06-05      9999-99-99        97    40
# 369361       1     2     2020-06-09      9999-99-99        97    40
#
#         RESULTADO  MIGRANTE
# 0               1        99
# 1               1        99
# 2               1        99
# 3               1        99
# ...

# %%
data_tab_def = data_tab_def[data_tab_def["FECHA_DEFUNCION"] != "9999-99-99"]

# %%
data_tab_def
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  \
# 11           2     1     2020-04-15      2020-05-06         2    62
# 15           2     2     2020-04-04      2020-04-13         2    61
# 16           2     2     2020-04-08      2020-04-09         2    72
# 22           2     2     2020-04-15      2020-05-11         2    74
# 34           2     2     2020-04-22      2020-05-03         2    57
# ...        ...   ...            ...             ...       ...   ...
# 369164       1     1     2020-05-29      2020-06-01         2    48
# 369204       1     1     2020-05-06      2020-05-11         2    43
# 369222       2     2     2020-05-15      2020-05-26         1    72
# 369325       2     2     2020-05-30      2020-06-05         2    59
# 369356       1     2     2020-05-06      2020-05-16         2    68
#
#         RESULTADO  MIGRANTE
# 11              1        99
# 15              1        99
# 16              1        99
# 22              1        99
# ...

# %%
data_tab_def["FECHA_DEFUNCION"] = pd.to_datetime(data_tab_def.FECHA_DEFUNCION)
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def.dtypes
# Out:
# ORIGEN                      int64
# SEXO                        int64
# FECHA_SINTOMAS     datetime64[ns]
# FECHA_DEFUNCION    datetime64[ns]
# INTUBADO                    int64
# EDAD                        int64
# RESULTADO                   int64
# MIGRANTE                    int64
# dtype: object

# %%
data_tab_def
# Out:
#         ORIGEN  SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  \
# 11           2     1     2020-04-15      2020-05-06         2    62
# 15           2     2     2020-04-04      2020-04-13         2    61
# 16           2     2     2020-04-08      2020-04-09         2    72
# 22           2     2     2020-04-15      2020-05-11         2    74
# 34           2     2     2020-04-22      2020-05-03         2    57
# ...        ...   ...            ...             ...       ...   ...
# 369164       1     1     2020-05-29      2020-06-01         2    48
# 369204       1     1     2020-05-06      2020-05-11         2    43
# 369222       2     2     2020-05-15      2020-05-26         1    72
# 369325       2     2     2020-05-30      2020-06-05         2    59
# 369356       1     2     2020-05-06      2020-05-16         2    68
#
#         RESULTADO  MIGRANTE
# 11              1        99
# 15              1        99
# 16              1        99
# 22              1        99
# ...

# %%
data[["EMBARAZO", "SEXO"]][:50]
#Sexo - 1 -> Mujer
#Sexo - 2 -> Hombre
# Out:
#     EMBARAZO  SEXO
# 0         97     2
# 1         97     2
# 2         97     2
# 3         97     2
# 4         97     2
# 5          2     1
# 6          2     1
# 7          2     1
# 8         97     2
# 9         97     2
# 10        97     2
# 11         2     1
# 12        97     2
# 13        97     2
# 14        97     2
# 15        97     2
# 16        97     2
# 17        97     2
# 18         2     1
# 19        97     2
# 20        97     2
# 21         2     1
# 22        97     2
# 23        97     2
# 24         2     1
# 25        97     2
# 26        97     2
# 27         2     1
# 28         2     1
# 29         2     1
# 30        97     2
# 31         2     1
# 32         2     1
# 33         2     1
# 34        97     2
# 35         2     1
# 36        97     2
# 37         2     1
# 38         2     1
# 39         2     1
# 40        97     2
# 41        97     2
# 42        97     2
# 43        97     2
# 44        97     2
# 45        97     2
# ...

# %%
data_tab_def["SEXO"] = np.where(data_tab_def["SEXO"] == 1, "Mujer", data_tab_def["SEXO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["SEXO"] = np.where(data_tab_def["SEXO"] == "2", "Hombre", data_tab_def["SEXO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
(data_tab_def["SEXO"] != "Hombre")
# Out:
# 11         True
# 15        False
# 16        False
# 22        False
# 34        False
#           ...
# 369164     True
# 369204     True
# 369222    False
# 369325    False
# 369356    False
# Name: SEXO, Length: 21566, dtype: bool

# %%
(data_tab_def["SEXO"] != "Mujer")
# Out:
# 11        False
# 15         True
# 16         True
# 22         True
# 34         True
#           ...
# 369164    False
# 369204    False
# 369222     True
# 369325     True
# 369356     True
# Name: SEXO, Length: 21566, dtype: bool

# %%
data_tab_def.head(10)
# Out:
#     ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION  INTUBADO  EDAD  RESULTADO  \
# 11       2   Mujer     2020-04-15      2020-05-06         2    62          1
# 15       2  Hombre     2020-04-04      2020-04-13         2    61          1
# 16       2  Hombre     2020-04-08      2020-04-09         2    72          1
# 22       2  Hombre     2020-04-15      2020-05-11         2    74          1
# 34       2  Hombre     2020-04-22      2020-05-03         2    57          1
# 45       2  Hombre     2020-04-05      2020-04-11         2    37          1
# 53       2   Mujer     2020-04-13      2020-04-22         2    60          1
# 54       2  Hombre     2020-04-16      2020-04-29         2    47          1
# 66       2  Hombre     2020-04-22      2020-04-28         2    63          1
# 76       2  Hombre     2020-05-11      2020-05-12        97    68          1
#
#     MIGRANTE
# 11        99
# 15        99
# 16        99
# 22        99
# 34        99
# 45        99
# 53        99
# ...

# %%
data_tab_def["INTUBADO"][:10]
# Out:
# 11     2
# 15     2
# 16     2
# 22     2
# 34     2
# 45     2
# 53     2
# 54     2
# 66     2
# 76    97
# Name: INTUBADO, dtype: int64

# %%
#data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "2", "si", data_tab_def["INTUBADO"])
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == 1, "no", data_tab_def["INTUBADO"])
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "97", "no", data_tab_def["INTUBADO"])
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == 99, "no", data_tab_def["INTUBADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "97", "no", data_tab_def["INTUBADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "99", "no", data_tab_def["INTUBADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "2", "si", data_tab_def["INTUBADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["INTUBADO"] = np.where(data_tab_def["INTUBADO"] == "1", "no", data_tab_def["INTUBADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def.head()
# Out:
#     ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION INTUBADO  EDAD  RESULTADO  \
# 11       2   Mujer     2020-04-15      2020-05-06       si    62          1
# 15       2  Hombre     2020-04-04      2020-04-13       si    61          1
# 16       2  Hombre     2020-04-08      2020-04-09       si    72          1
# 22       2  Hombre     2020-04-15      2020-05-11       si    74          1
# 34       2  Hombre     2020-04-22      2020-05-03       si    57          1
#
#     MIGRANTE
# 11        99
# 15        99
# 16        99
# 22        99
# 34        99

# %%
data_tab_def["INTUBADO"].unique()
# Out:
# array(['si', 'no'], dtype=object)

# %%
data_tab_def.head(15)
# Out:
#      ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION INTUBADO  EDAD  RESULTADO  \
# 11        2   Mujer     2020-04-15      2020-05-06       si    62          1
# 15        2  Hombre     2020-04-04      2020-04-13       si    61          1
# 16        2  Hombre     2020-04-08      2020-04-09       si    72          1
# 22        2  Hombre     2020-04-15      2020-05-11       si    74          1
# 34        2  Hombre     2020-04-22      2020-05-03       si    57          1
# 45        2  Hombre     2020-04-05      2020-04-11       si    37          1
# 53        2   Mujer     2020-04-13      2020-04-22       si    60          1
# 54        2  Hombre     2020-04-16      2020-04-29       si    47          1
# 66        2  Hombre     2020-04-22      2020-04-28       si    63          1
# 76        2  Hombre     2020-05-11      2020-05-12       no    68          1
# 82        2  Hombre     2020-05-03      2020-05-27       si    51          1
# ...

# %%
data_tab_def["MIGRANTE"] = np.where(data_tab_def["MIGRANTE"] == "99", "no", data_tab_def["MIGRANTE"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["MIGRANTE"] = np.where(data_tab_def["MIGRANTE"] != "no", "si", data_tab_def["MIGRANTE"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["MIGRANTE"].unique()
# Out:
# array(['si'], dtype=object)

# %%
data_tab_def
# Out:
#         ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION INTUBADO  EDAD  \
# 11           2   Mujer     2020-04-15      2020-05-06       si    62
# 15           2  Hombre     2020-04-04      2020-04-13       si    61
# 16           2  Hombre     2020-04-08      2020-04-09       si    72
# 22           2  Hombre     2020-04-15      2020-05-11       si    74
# 34           2  Hombre     2020-04-22      2020-05-03       si    57
# ...        ...     ...            ...             ...      ...   ...
# 369164       1   Mujer     2020-05-29      2020-06-01       si    48
# 369204       1   Mujer     2020-05-06      2020-05-11       si    43
# 369222       2  Hombre     2020-05-15      2020-05-26       no    72
# 369325       2  Hombre     2020-05-30      2020-06-05       si    59
# 369356       1  Hombre     2020-05-06      2020-05-16       si    68
#
#         RESULTADO MIGRANTE
# 11              1       si
# 15              1       si
# 16              1       si
# ...

# %%
data_tab_def.groupby("SEXO").mean()
# Out:
#           ORIGEN       EDAD  RESULTADO
# SEXO
# Hombre  1.411409  59.492309   1.344538
# Mujer   1.402446  61.605263   1.377326

# %%
data_tab_def["RESULTADO"] =np.where(data_tab_def["RESULTADO"] == 1, "Positivo", data_tab_def["RESULTADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def
# Out:
#         ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION INTUBADO  EDAD  \
# 11           2   Mujer     2020-04-15      2020-05-06       si    62
# 15           2  Hombre     2020-04-04      2020-04-13       si    61
# 16           2  Hombre     2020-04-08      2020-04-09       si    72
# 22           2  Hombre     2020-04-15      2020-05-11       si    74
# 34           2  Hombre     2020-04-22      2020-05-03       si    57
# ...        ...     ...            ...             ...      ...   ...
# 369164       1   Mujer     2020-05-29      2020-06-01       si    48
# 369204       1   Mujer     2020-05-06      2020-05-11       si    43
# 369222       2  Hombre     2020-05-15      2020-05-26       no    72
# 369325       2  Hombre     2020-05-30      2020-06-05       si    59
# 369356       1  Hombre     2020-05-06      2020-05-16       si    68
#
#        RESULTADO MIGRANTE
# 11      Positivo       si
# 15      Positivo       si
# 16      Positivo       si
# 22      Positivo       si
# ...

# %%
data_tab_def["RESULTADO"] =np.where(data_tab_def["RESULTADO"] == "2", "Negativo", data_tab_def["RESULTADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def["RESULTADO"] =np.where(data_tab_def["RESULTADO"] == "3", "Sospechoso", data_tab_def["RESULTADO"])
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_tab_def
# Out:
#         ORIGEN    SEXO FECHA_SINTOMAS FECHA_DEFUNCION INTUBADO  EDAD  \
# 11           2   Mujer     2020-04-15      2020-05-06       si    62
# 15           2  Hombre     2020-04-04      2020-04-13       si    61
# 16           2  Hombre     2020-04-08      2020-04-09       si    72
# 22           2  Hombre     2020-04-15      2020-05-11       si    74
# 34           2  Hombre     2020-04-22      2020-05-03       si    57
# ...        ...     ...            ...             ...      ...   ...
# 369164       1   Mujer     2020-05-29      2020-06-01       si    48
# 369204       1   Mujer     2020-05-06      2020-05-11       si    43
# 369222       2  Hombre     2020-05-15      2020-05-26       no    72
# 369325       2  Hombre     2020-05-30      2020-06-05       si    59
# 369356       1  Hombre     2020-05-06      2020-05-16       si    68
#
#          RESULTADO MIGRANTE
# 11        Positivo       si
# 15        Positivo       si
# 16        Positivo       si
# ...

# %%
plt.hist(data_tab_def["FECHA_SINTOMAS"], bins=20)
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# (array([4.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 3.000e+00, 1.000e+00,
#         1.000e+00, 1.200e+01, 4.200e+01, 1.940e+02, 6.670e+02, 1.127e+03,
#         1.713e+03, 2.411e+03, 2.485e+03, 3.509e+03, 3.719e+03, 3.215e+03,
#         2.031e+03, 4.300e+02]),
#  array([737429. , 737436.8, 737444.6, 737452.4, 737460.2, 737468. ,
#         737475.8, 737483.6, 737491.4, 737499.2, 737507. , 737514.8,
#         737522.6, 737530.4, 737538.2, 737546. , 737553.8, 737561.6,
# ...

# %%
plt.hist(data_tab_def["FECHA_DEFUNCION"], bins=20)
# Out:
# (array([2.000e+00, 0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 6.000e+00,
#         1.000e+00, 4.000e+00, 8.000e+00, 5.300e+01, 3.730e+02, 6.710e+02,
#         1.134e+03, 1.579e+03, 2.024e+03, 2.833e+03, 3.121e+03, 3.769e+03,
#         3.250e+03, 2.735e+03]),
#  array([737438. , 737445.4, 737452.8, 737460.2, 737467.6, 737475. ,
#         737482.4, 737489.8, 737497.2, 737504.6, 737512. , 737519.4,
#         737526.8, 737534.2, 737541.6, 737549. , 737556.4, 737563.8,
#         737571.2, 737578.6, 737586. ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data_tab_def["EDAD"],bins=30)
# Out:
# (array([ 160.,   14.,   31.,   21.,   36.,   45.,  105.,  138.,  206.,
#          389.,  388.,  764.,  757., 1417., 1272., 1471., 2188., 1721.,
#         2145., 1632., 1911., 1209., 1056., 1061.,  610.,  486.,  192.,
#          100.,   32.,    9.]),
#  array([  0.        ,   3.43333333,   6.86666667,  10.3       ,
#          13.73333333,  17.16666667,  20.6       ,  24.03333333,
#          27.46666667,  30.9       ,  34.33333333,  37.76666667,
#          41.2       ,  44.63333333,  48.06666667,  51.5       ,
#          54.93333333,  58.36666667,  61.8       ,  65.23333333,
#          68.66666667,  72.1       ,  75.53333333,  78.96666667,
#          82.4       ,  85.83333333,  89.26666667,  92.7       ,
#          96.13333333,  99.56666667, 103.        ]),
#  <a list of 30 Patch objects>)

# %%
data_tab_def.dtypes
# Out:
# ORIGEN                      int64
# SEXO                       object
# FECHA_SINTOMAS     datetime64[ns]
# FECHA_DEFUNCION    datetime64[ns]
# INTUBADO                   object
# EDAD                        int64
# RESULTADO                  object
# MIGRANTE                   object
# dtype: object

# %%
plt.plot(data_tab_def["FECHA_DEFUNCION"], data_tab_def["EDAD"])

# %% [markdown]
# ### Tabaquismo - NO defuncion

# %%
#data_new = data_new[data_new["FECHA_DEF"] != "9999-99-99"]

# %%
#data_new = data_new[data_new["RESULTADO"] == 1]

# %%
#data_new

# %%
#data_new["TABAQUISMO"] = np.where(data_new["TABAQUISMO"] == "1" , "Si", data_new["TABAQUISMO"])
#data_new["TABAQUISMO"] = np.where(data_new["TABAQUISMO"] == "2" , "No", data_new["TABAQUISMO"])
