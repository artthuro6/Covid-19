# %% [markdown]
# ### Bibliotecas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("../datasets/200610COVID19MEXICO.csv")

# %%
data.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
data.head(3)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-06-10      0f69b4       2       3          15     2
# 1          2020-06-10      1c79cc       2       3          15     2
# 2          2020-06-10      140aab       2       4           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0            7           15            106              1  ...              2
# 1           15           15            106              2  ...              2
# 2            9            9              7              1  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# 0        2             2           2          1          1        99
# 1        2             2           2          2          1        99
# 2        2             2           2         99          1        99
#
#    PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0             México           99   97
# 1             México           99    2
# 2             México           99   97
#
# [3 rows x 35 columns]

# %%
data[data["PAIS_NACIONALIDAD"] == "México"]
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-06-10      0f69b4       2       3          15     2
# 1               2020-06-10      1c79cc       2       3          15     2
# 2               2020-06-10      140aab       2       4           9     2
# 3               2020-06-10      051c09       2       4           2     2
# 4               2020-06-10      1c8c37       2       4           9     2
# ...                    ...         ...     ...     ...         ...   ...
# 369356          2020-06-10      147944       1       4          25     2
# 369358          2020-06-10      08009f       1       4           5     2
# 369359          2020-06-10      077eca       2      12          15     1
# 369360          2020-06-10      16b2f3       2      12          27     1
# 369361          2020-06-10      15aafe       1       4          25     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                 7           15            106              1  ...
# 1                15           15            106              2  ...
# 2                 9            9              7              1  ...
# 3                 2            2              4              1  ...
# 4                15           15             58              2  ...
# ...             ...          ...            ...            ...  ...
# 369356           25           25              6              2  ...
# 369358            5            5              4              2  ...
# 369359            9           15             81              1  ...
# 369360           20           27             15              1  ...
# 369361           25           25             11              1  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                   2        2             2           2          1
# 1                   2        2             2           2          2
# 2                   2        2             2           2         99
# 3                   2        2             2           2         99
# 4                   2        2             2           2         99
# ...               ...      ...           ...         ...        ...
# 369356              1        2             2           2         99
# 369358              2        2             2           1         99
# 369359              2        2             2           2          1
# 369360              2        1             2           2          1
# 369361              2        2             2           2         99
#
#         RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0               1        99             México           99   97
# 1               1        99             México           99    2
# 2               1        99             México           99   97
# 3               1        99             México           99   97
# 4               1        99             México           99    2
# ...           ...       ...                ...          ...  ...
# 369356          3        99             México           99    2
# 369358          3        99             México           99    2
# 369359          3        99             México           99   97
# 369360          3        99             México           99   97
# 369361          3        99             México           99   97
#
# [366940 rows x 35 columns]

# %%
data["SEXO"].unique()
# Out:
# array([2, 1])

# %%
data["SEXO"].value_counts()
# Out:
# 2    188276
# 1    181086
# Name: SEXO, dtype: int64

# %%
data["SEXO"] = np.where(data["SEXO"] == "1", "Femenino", data["SEXO"])
data["SEXO"] = np.where(data["SEXO"] == "2", "Masculino", data["SEXO"])

# %%
data["SEXO"].unique()
# Out:
# array(['Masculino', 'Femenino'], dtype=object)

# %%
data
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM       SEXO  \
# 0               2020-06-10      0f69b4       2       3          15  Masculino
# 1               2020-06-10      1c79cc       2       3          15  Masculino
# 2               2020-06-10      140aab       2       4           9  Masculino
# 3               2020-06-10      051c09       2       4           2  Masculino
# 4               2020-06-10      1c8c37       2       4           9  Masculino
# ...                    ...         ...     ...     ...         ...        ...
# 369357          2020-06-10      081dda       2      12          15  Masculino
# 369358          2020-06-10      08009f       1       4           5  Masculino
# 369359          2020-06-10      077eca       2      12          15   Femenino
# 369360          2020-06-10      16b2f3       2      12          27   Femenino
# 369361          2020-06-10      15aafe       1       4          25  Masculino
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                 7           15            106              1  ...
# 1                15           15            106              2  ...
# 2                 9            9              7              1  ...
# 3                 2            2              4              1  ...
# 4                15           15             58              2  ...
# ...             ...          ...            ...            ...  ...
# 369357           99            9             14              1  ...
# 369358            5            5              4              2  ...
# 369359            9           15             81              1  ...
# 369360           20           27             15              1  ...
# 369361           25           25             11              1  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                   2        2             2           2          1
# 1                   2        2             2           2          2
# 2                   2        2             2           2         99
# 3                   2        2             2           2         99
# 4                   2        2             2           2         99
# ...               ...      ...           ...         ...        ...
# 369357              2        2             2           2          1
# 369358              2        2             2           1         99
# 369359              2        2             2           2          1
# 369360              2        1             2           2          1
# 369361              2        2             2           2         99
#
#         RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0               1        99             México           99   97
# 1               1        99             México           99    2
# 2               1        99             México           99   97
# 3               1        99             México           99   97
# 4               1        99             México           99    2
# ...           ...       ...                ...          ...  ...
# 369357          3         2            Bolivia           99   97
# 369358          3        99             México           99    2
# 369359          3        99             México           99   97
# 369360          3        99             México           99   97
# 369361          3        99             México           99   97
#
# [369362 rows x 35 columns]

# %%
data["RESULTADO"] = np.where(data["RESULTADO"] == "3", "Sospechoso", data["RESULTADO"])
data["RESULTADO"] = np.where(data["RESULTADO"] == "2", "Negativo", data["RESULTADO"])
data["RESULTADO"] = np.where(data["RESULTADO"] == "1", "Positivo", data["RESULTADO"])

# %%
data["RESULTADO"].unique()
# Out:
# array([1, 2])

# %%
data.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
# 15               2         2              2              2           2
# 16               1         1              2              2           2
# 17               2         2              2              2           2
# 18               2         2              2              2           2
# 19               2         2              2              2           2
#
#    RESULTADO  EDAD
# 0   Positivo    53
# 1   Positivo    59
# 2   Positivo    34
# 3   Positivo    45
# 4   Positivo    53
# 5   Positivo    64
# 6   Positivo    29
# 7   Positivo    41
# 8   Positivo    53
# 9   Positivo    26
# 10  Positivo    52
# 11  Positivo    62
# 12  Positivo    43
# 13  Positivo    34
# 14  Positivo    56
# 15  Positivo    61
# 16  Positivo    72
# 17  Positivo    56
# 18  Positivo    48
# 19  Positivo    45

# %%
df["NEUMONIA"].unique()
# Out:
# array([ 2,  1, 99])

# %%
# 2 y 9.. es NO

# %%
df["NEUMONIA"] = toOther(df, ["NEUMONIA"], "2" , "No")
# Out:
# <ipython-input-44-ad25bc836932>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NEUMONIA"] = toOther(df, ["NEUMONIA"], "2" , "No")

# %%
df["NEUMONIA"] = toOther(df, ["NEUMONIA"], "1" , "Si")
# Out:
# <ipython-input-47-c8bcd669ff42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NEUMONIA"] = toOther(df, ["NEUMONIA"], "1" , "Si")

# %%
df
# Out:
#              SEXO  ENTIDAD_NAC FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  \
# 0       Masculino            7    2020-05-27     2020-05-25  9999-99-99
# 1       Masculino           15    2020-06-04     2020-05-31  9999-99-99
# 2       Masculino            9    2020-04-27     2020-04-20  9999-99-99
# 3       Masculino            2    2020-04-30     2020-04-24  9999-99-99
# 4       Masculino           15    2020-05-05     2020-04-23  9999-99-99
# ...           ...          ...           ...            ...         ...
# 369357  Masculino           99    2020-06-01     2020-05-27  9999-99-99
# 369358  Masculino            5    2020-04-20     2020-04-19  9999-99-99
# 369359   Femenino            9    2020-06-10     2020-06-09  9999-99-99
# 369360   Femenino           20    2020-06-10     2020-06-05  9999-99-99
# 369361  Masculino           25    2020-06-10     2020-06-09  9999-99-99
#
#         INTUBADO NEUMONIA  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0             97       No        97         1     2     2         2
# 1              2       Si        97         2     2     2         2
# 2             97       No        97         2     2     2         2
# 3             97       No        97         2     2     2         2
# 4              2       Si        97         2     2     2         2
# ...          ...      ...       ...       ...   ...   ...       ...
# 369357        97       No        97         2     2     2         2
# 369358         2       No        97         1     2     2         2
# 369359        97       No         2         2     2     2         2
# 369360        97       No         2         2     2     2         2
# 369361        97       No        97         2     2     2         2
#
#         HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  RENAL_CRONICA  \
# 0                  2               2         2              2              2
# 1                  2               2         2              2              2
# 2                  2               2         2              2              2
# 3                  2               2         2              2              2
# 4                  1               2         2              2              2
# ...              ...             ...       ...            ...            ...
# 369357             2               2         2              2              2
# 369358             2               2         2              2              2
# 369359             2               2         2              2              2
# 369360             2               2         1              2              2
# 369361             2               2         2              2              2
#
#         TABAQUISMO   RESULTADO  EDAD
# 0                2    Positivo    53
# 1                2    Positivo    59
# 2                2    Positivo    34
# 3                2    Positivo    45
# 4                2    Positivo    53
# ...            ...         ...   ...
# 369357           2  Sospechoso    51
# 369358           1  Sospechoso    96
# 369359           2  Sospechoso    46
# 369360           2  Sospechoso    40
# 369361           2  Sospechoso    40
#
# [369362 rows x 20 columns]

# %%
def toOther(data, nameColumna, aSustituir, sustituto):
    
    return (np.where(data[nameColumna] == aSustituir, sustituto, data[nameColumna]))
